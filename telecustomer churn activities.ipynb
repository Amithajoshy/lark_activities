# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r'C:\\Users\\hp\\Desktop\\Data Science Activites\\Telco-Customer-Churn.csv')

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineBackup  ... DeviceProtection  \
# 0  No phone service             DSL          Yes  ...               No
# 1                No             DSL           No  ...              Yes
# 2                No             DSL          Yes  ...               No
# 3  No phone service             DSL           No  ...              Yes
# 4                No     Fiber optic           No  ...               No
#
# ...

# %%
data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineBackup', 'OnlineSecurity', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %% [markdown]
# # 1. Compare churn count with respect to gender

# %%
plt.figure(figsize=(5,5))
sns.countplot( x='gender',hue='Churn',data=data) 
plt.title('Churn count respect to the gender',fontweight="bold")
plt.grid(linestyle="--")  
plt.show()

# %% [markdown]
# # 2. Find out how many female senior citizens there in the dataset

# %%
data1=data[(data['gender']=='Female') & (data['SeniorCitizen']==1)]
data1['gender'].count()
plt.figure(figsize=(6,6))
sns.countplot( x='gender',hue='SeniorCitizen',data=data1) 
plt.title("Count of female senior citizens ")
# Out:
# Text(0.5, 1.0, 'Count of female senior citizens ')

# %% [markdown]
# # 3. Compare 'tenure' with 'Total Charges

# %%
plt.figure(figsize=(8,6))
plt.scatter(data['tenure'] , data['TotalCharges'] , s=11 , c='orange')
plt.title("Tenure VS Total charges",fontweight="bold")
plt.xlabel('Tenure')
plt.ylabel('Total Charges')
# Out:
# Text(0, 0.5, 'Total Charges')

# %% [markdown]
# # 4. Find out which contract is preferred by the senior citizen

# %%
plt.figure(figsize=(8,6))
sns.countplot(data1['Contract'])
plt.title('Contract preference of SeniorCitizens', fontsize=15)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Contract preference of SeniorCitizens')

# %% [markdown]
# # 5 Comment on your finds on Payment Method?

# %%
plt.figure(figsize=(10,8))
sns.countplot(x='PaymentMethod', hue='gender' , data=data)
plt.title("Payment method VS Gender" , fontsize='14')
# Out:
# Text(0.5, 1.0, 'Payment method VS Gender')

# %%
plt.figure(figsize=(10,10))
sns.countplot(data['PaymentMethod'])
plt.title('PAYMENT METHODS')
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'PAYMENT METHODS')

# %%
plt.figure(figsize=(10,6))
sns.countplot(data1['PaymentMethod'])
plt.title('PaymentMethod preference of SeniorCitizen' , fontsize=15)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'PaymentMethod preference of SeniorCitizen')
