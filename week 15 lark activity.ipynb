# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\hp\Desktop\Data Science Activites\titanic_dataset (1).csv",index_col = 'PassengerId')
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
df.describe(include = "all")
# Out:
#           Survived      Pclass                     Name   Sex         Age  \
# count   891.000000  891.000000                      891   891  714.000000
# unique         NaN         NaN                      891     2         NaN
# top            NaN         NaN  Braund, Mr. Owen Harris  male         NaN
# freq           NaN         NaN                        1   577         NaN
# mean      0.383838    2.308642                      NaN   NaN   29.699118
# std       0.486592    0.836071                      NaN   NaN   14.526497
# min       0.000000    1.000000                      NaN   NaN    0.420000
# 25%       0.000000    2.000000                      NaN   NaN   20.125000
# 50%       0.000000    3.000000                      NaN   NaN   28.000000
# 75%       1.000000    3.000000                      NaN   NaN   38.000000
# max       1.000000    3.000000                      NaN   NaN   80.000000
#
#              SibSp       Parch  Ticket        Fare    Cabin Embarked
# ...

# %%
df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
sns.set(rc={'axes.facecolor':'white', 'figure.facecolor':'yellow'})

columns =["Pclass","Sex","SibSp","Parch","Embarked" ]

for i in columns:
    plt.figure(figsize=(15,30))
    plt.subplot(len(i), 2, 1)
    sns.countplot(x=df[i],order=df[i].value_counts().index,palette="viridis")
    plt.title('Distribution of {}'.format(i))
    
    plt.subplot(len(i), 2, 2)
    sns.countplot(x=df[i],order=df[i].value_counts().index,hue=df["Survived"],palette="inferno")
    plt.title('Distribution of {} with respect to survived'.format(i))
    plt.show()

# %%
CrosstabResult=pd.crosstab(index=df['Pclass'],columns=df['Survived'])
CrosstabResult.plot.bar()
plt.legend(('Died', 'Survived'), loc='best')

# %%
corrmatrix=df.corr()
plt.subplots(figsize=(20,10))
sns.heatmap(corrmatrix,vmin=-2,vmax=.9,annot=True,linewidth=0.2,cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %%
#filling of missing values

# %%
d=df['Name'].str.split(',',expand=True)
d
# Out:
#                      0                                            1
# PassengerId
# 1               Braund                              Mr. Owen Harris
# 2              Cumings   Mrs. John Bradley (Florence Briggs Thayer)
# 3            Heikkinen                                  Miss. Laina
# 4             Futrelle           Mrs. Jacques Heath (Lily May Peel)
# 5                Allen                            Mr. William Henry
# ...                ...                                          ...
# 887           Montvila                                  Rev. Juozas
# 888             Graham                         Miss. Margaret Edith
# 889           Johnston               Miss. Catherine Helen "Carrie"
# 890               Behr                              Mr. Karl Howell
# 891             Dooley                                  Mr. Patrick
#
# [891 rows x 2 columns]

# %%
d1=d[1].str.split('.',expand=True)
d1
# Out:
#                  0                                       1     2
# PassengerId
# 1               Mr                             Owen Harris  None
# 2              Mrs   John Bradley (Florence Briggs Thayer)  None
# 3             Miss                                   Laina  None
# 4              Mrs           Jacques Heath (Lily May Peel)  None
# 5               Mr                           William Henry  None
# ...            ...                                     ...   ...
# 887            Rev                                  Juozas  None
# 888           Miss                          Margaret Edith  None
# 889           Miss                Catherine Helen "Carrie"  None
# 890             Mr                             Karl Howell  None
# 891             Mr                                 Patrick  None
#
# [891 rows x 3 columns]

# %%
d2=d1.drop([1,2],axis=1)
d2
# Out:
#                  0
# PassengerId
# 1               Mr
# 2              Mrs
# 3             Miss
# 4              Mrs
# 5               Mr
# ...            ...
# 887            Rev
# 888           Miss
# 889           Miss
# 890             Mr
# 891             Mr
#
# [891 rows x 1 columns]

# %%
data=pd.concat([df,d2],axis=1)
data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
data=data.rename(columns={data.columns[-1]:'title'})
data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
data.groupby('title')['Age'].mean()
# Out:
# title
#  Capt            70.000000
#  Col             58.000000
#  Don             40.000000
#  Dr              42.000000
#  Jonkheer        38.000000
#  Lady            48.000000
#  Major           48.500000
#  Master           4.574167
#  Miss            21.773973
#  Mlle            24.000000
#  Mme             24.000000
#  Mr              32.368090
#  Mrs             35.898148
#  Ms              28.000000
#  Rev             43.166667
#  Sir             49.000000
#  the Countess    33.000000
# Name: Age, dtype: float64

# %%
data['Age']=data['Age'].fillna(data.groupby('title')['Age'].transform('mean'))
data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3                                       Heikkinen, Miss. Laina  female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 5                                     Allen, Mr. William Henry    male
# ...                                                        ...     ...
# ...

# %%
data.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age           0
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# title         0
# dtype: int64

# %%
data['Embarked'] = data['Embarked'].fillna(data['Embarked'].mode()[0])
data.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age           0
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      0
# title         0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

imp = SimpleImputer(missing_values=np.nan, strategy='most_frequent')

imp = imp.fit(data[['Cabin']])
data['Cabin'] = imp.transform(data[['Cabin']]).ravel()

# %%
data.isna().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Cabin       0
# Embarked    0
# title       0
# dtype: int64

# %%
data2=data
data2
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3                                       Heikkinen, Miss. Laina  female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 5                                     Allen, Mr. William Henry    male
# ...                                                        ...     ...
# ...

# %%
data.plot(kind='box', vert=True)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(y=data2["SibSp"])
# Out:
# <AxesSubplot:ylabel='SibSp'>

# %%
sns.boxplot(y=data2["Age"])
# Out:
# <AxesSubplot:ylabel='Age'>

# %%
sns.boxplot(y=data2["Parch"])
# Out:
# <AxesSubplot:ylabel='Parch'>

# %%
sns.boxplot(y=data2["Fare"])
# Out:
# <AxesSubplot:ylabel='Fare'>

# %%
#Using percentile and IQR method we are dealing with the outlier

# %%
Q1 = np.percentile(data2['SibSp'],25,interpolation = 'midpoint')
Q2 = np.percentile(data2['SibSp'],50,interpolation = 'midpoint')
Q3 = np.percentile(data2['SibSp'],75,interpolation = 'midpoint')

IQR = Q3-Q1
lower_limit = Q1 - (1.5*IQR)
upper_limit = Q3 + (1.5*IQR)

print("IQR is ",IQR)
print("Lower limit is" ,lower_limit)
print("Upper Limit is",upper_limit)
# Out:
# IQR is  1.0
# Lower limit is -1.5
# Upper Limit is 2.5

# %%
index=data2['SibSp'][(data2['SibSp']>upper_limit)|(data2['SibSp']<lower_limit)].index
data2.drop(index,inplace=True)

# %%
#The outliers will be dropped for all the values which are outside the upper and lower limit

# %%
sns.boxplot(y=data2["SibSp"])
# Out:
# <AxesSubplot:ylabel='SibSp'>

# %%
Q1 = np.percentile(data2['Age'],25,interpolation = 'midpoint')
Q2 = np.percentile(data2['Age'],50,interpolation = 'midpoint')
Q3 = np.percentile(data2['Age'],75,interpolation = 'midpoint')

IQR = Q3-Q1
lower_limit = Q1 - (1.5*IQR)
upper_limit = Q3 + (1.5*IQR)

print("IQR is ",IQR)
print("Lower limit is" ,lower_limit)
print("Upper Limit is",upper_limit)
# Out:
# IQR is  14.0
# Lower limit is 1.0
# Upper Limit is 57.0

# %%
#In case of age , we replace values outside upper limit with upper limit
#Values below lower limit with lower limit

# %%
data2['Age']=np.where(data2['Age']>upper_limit,upper_limit,np.where(data2['Age']<lower_limit,lower_limit,data2['Age']))

# %%
sns.boxplot(y=data2["Age"])
# Out:
# <AxesSubplot:ylabel='Age'>

# %%
Q1 = np.percentile(data2['Fare'],25,interpolation = 'midpoint')
Q2 = np.percentile(data2['Fare'],50,interpolation = 'midpoint')
Q3 = np.percentile(data2['Fare'],75,interpolation = 'midpoint')

IQR = Q3-Q1
lower_limit = Q1 - (1.5*IQR)
upper_limit = Q3 + (1.5*IQR)

print("IQR is ",IQR)
print("Lower limit is" ,lower_limit)
print("Upper Limit is",upper_limit)
# Out:
# IQR is  22.1042
# Lower limit is -25.2605
# Upper Limit is 63.1563

# %%
#In case of fate , we replace values outside upper limit with upper limit
#Values below lower limit with lower limit

# %%
data2['Fare']=np.where(data2['Fare']>upper_limit,upper_limit,np.where(data2['Fare']<lower_limit,lower_limit,data2['Fare']))

# %%
sns.boxplot(y=data2["Age"])
# Out:
# <AxesSubplot:ylabel='Age'>

# %%
#FEATURE ENIGNEERING

# %%
#We can combine SibSp and Parch into one synthetic feature called family size, which indicates the total number of 
#family members on board for each member

# %%
data2['Family_Size']=data2['SibSp']+data2['Parch']+1
data2
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3                                       Heikkinen, Miss. Laina  female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 5                                     Allen, Mr. William Henry    male
# ...                                                        ...     ...
# ...

# %%
data2.drop('Cabin',axis=1,inplace=True)
data2.drop('Name',axis=1,inplace=True)
data2.drop('title',axis=1,inplace=True)
data2.drop('parch',axis=1,inplace=True)
data2.drop('SibSp',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11712/1112429361.py in <module>
# ----> 1 data2.drop('Cabin',axis=1,inplace=True)
#       2 data2.drop('Name',axis=1,inplace=True)
#       3 data2.drop('title',axis=1,inplace=True)
#       4 data2.drop('parch',axis=1,inplace=True)
#       5 data2.drop('SibSp',axis=1,inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
# ...
