# %%
import numpy as np
import pandas as pd
from pandas import Series ,DataFrame
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
datatrain1=pd.read_csv(r"C:\Users\hp\Desktop\boot camp\train.csv")
datatrain1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
datatest2=pd.read_csv(r"C:\Users\hp\Desktop\boot camp\test.csv")

# %%
datatest2
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
data=pd.concat([datatrain1,datatest2])
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# dtype: int64

# %%
data.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.038354  0.028814 -0.055224  0.008942
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.038354 -0.338481  1.000000 -0.408106  0.060832  0.018322
# Age             0.028814 -0.077221 -0.408106  1.000000 -0.243699 -0.150917
# SibSp          -0.055224 -0.035322  0.060832 -0.243699  1.000000  0.373587
# Parch           0.008942  0.081629  0.018322 -0.150917  0.373587  1.000000
# Fare            0.031428  0.257307 -0.558629  0.178740  0.160238  0.221539
#
#                  Fare
# PassengerId  0.031428
# Survived     0.257307
# Pclass      -0.558629
# Age          0.178740
# SibSp        0.160238
# Parch        0.221539
# Fare         1.000000

# %%
corrmatrix=data.corr()
plt.subplots(figsize=(10,4))
sns.heatmap(corrmatrix,vmin=-2,vmax=.9,annot=True,linewidth=0.2,cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %%
data.set_index('PassengerId',inplace=True)
data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                 0.0       3
# 2                 1.0       1
# 3                 1.0       3
# 4                 1.0       1
# 5                 0.0       3
# ...               ...     ...
# 1305              NaN       3
# 1306              NaN       1
# 1307              NaN       3
# 1308              NaN       3
# 1309              NaN       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
d=data['Name'].str.split(',',expand=True)
d
# Out:
#                          0                                            1
# PassengerId
# 1                   Braund                              Mr. Owen Harris
# 2                  Cumings   Mrs. John Bradley (Florence Briggs Thayer)
# 3                Heikkinen                                  Miss. Laina
# 4                 Futrelle           Mrs. Jacques Heath (Lily May Peel)
# 5                    Allen                            Mr. William Henry
# ...                    ...                                          ...
# 1305               Spector                                    Mr. Woolf
# 1306         Oliva y Ocana                                Dona. Fermina
# 1307               Saether                          Mr. Simon Sivertsen
# 1308                  Ware                                Mr. Frederick
# 1309                 Peter                            Master. Michael J
#
# [1309 rows x 2 columns]

# %%
d1=d[1].str.split('.',expand=True)
d1
# Out:
#                    0                                       1     2
# PassengerId
# 1                 Mr                             Owen Harris  None
# 2                Mrs   John Bradley (Florence Briggs Thayer)  None
# 3               Miss                                   Laina  None
# 4                Mrs           Jacques Heath (Lily May Peel)  None
# 5                 Mr                           William Henry  None
# ...              ...                                     ...   ...
# 1305              Mr                                   Woolf  None
# 1306            Dona                                 Fermina  None
# 1307              Mr                         Simon Sivertsen  None
# 1308              Mr                               Frederick  None
# 1309          Master                               Michael J  None
#
# [1309 rows x 3 columns]

# %%
d2=d1.drop([1,2],axis=1)
d2
# Out:
#                    0
# PassengerId
# 1                 Mr
# 2                Mrs
# 3               Miss
# 4                Mrs
# 5                 Mr
# ...              ...
# 1305              Mr
# 1306            Dona
# 1307              Mr
# 1308              Mr
# 1309          Master
#
# [1309 rows x 1 columns]

# %%
data=pd.concat([data,d2],axis=1)
data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                 0.0       3
# 2                 1.0       1
# 3                 1.0       3
# 4                 1.0       1
# 5                 0.0       3
# ...               ...     ...
# 1305              NaN       3
# 1306              NaN       1
# 1307              NaN       3
# 1308              NaN       3
# 1309              NaN       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
data=data.rename(columns={data.columns[-1]:'title'})
data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                 0.0       3
# 2                 1.0       1
# 3                 1.0       3
# 4                 1.0       1
# 5                 0.0       3
# ...               ...     ...
# 1305              NaN       3
# 1306              NaN       1
# 1307              NaN       3
# 1308              NaN       3
# 1309              NaN       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
data.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked', 'title'],
#       dtype='object')

# %%
df=data[['Survived', 'Pclass','title','Sex', 'Age', 'SibSp', 'Parch',]]

# %%
df
# Out:
#              Survived  Pclass    title     Sex   Age  SibSp  Parch
# PassengerId
# 1                 0.0       3       Mr    male  22.0      1      0
# 2                 1.0       1      Mrs  female  38.0      1      0
# 3                 1.0       3     Miss  female  26.0      0      0
# 4                 1.0       1      Mrs  female  35.0      1      0
# 5                 0.0       3       Mr    male  35.0      0      0
# ...               ...     ...      ...     ...   ...    ...    ...
# 1305              NaN       3       Mr    male   NaN      0      0
# 1306              NaN       1     Dona  female  39.0      0      0
# 1307              NaN       3       Mr    male  38.5      0      0
# 1308              NaN       3       Mr    male   NaN      0      0
# 1309              NaN       3   Master    male   NaN      1      1
#
# [1309 rows x 7 columns]

# %%
df.groupby('title')['Age'].mean()
# Out:
# title
#  Capt            70.000000
#  Col             54.000000
#  Don             40.000000
#  Dona            39.000000
#  Dr              43.571429
#  Jonkheer        38.000000
#  Lady            48.000000
#  Major           48.500000
#  Master           5.482642
#  Miss            21.774238
#  Mlle            24.000000
#  Mme             24.000000
#  Mr              32.252151
#  Mrs             36.994118
#  Ms              28.000000
#  Rev             41.250000
#  Sir             49.000000
#  the Countess    33.000000
# Name: Age, dtype: float64

# %%
df['Age']=df['Age'].fillna(df.groupby('title')['Age'].transform('mean'))
df
# Out:
# C:\Users\hp\AppData\Local\Temp/ipykernel_11652/2688411309.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age']=df['Age'].fillna(df.groupby('title')['Age'].transform('mean'))
#              Survived  Pclass    title     Sex        Age  SibSp  Parch
# PassengerId
# 1                 0.0       3       Mr    male  22.000000      1      0
# 2                 1.0       1      Mrs  female  38.000000      1      0
# 3                 1.0       3     Miss  female  26.000000      0      0
# 4                 1.0       1      Mrs  female  35.000000      1      0
# 5                 0.0       3       Mr    male  35.000000      0      0
# ...               ...     ...      ...     ...        ...    ...    ...
# ...

# %%
df.isna().sum()
# Out:
# Survived    418
# Pclass        0
# title         0
# Sex           0
# Age           0
# SibSp         0
# Parch         0
# dtype: int64

# %%
corrmatrix=df.corr()
plt.subplots(figsize=(10,4))
sns.heatmap(corrmatrix,vmin=-2,vmax=.9,annot=True,linewidth=0.2,cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df)

# %%
plt.figure(figsize=(15,8))

sns.countplot(df['title'])
plt.grid()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
for i in df.columns:
    sns.barplot(df[i].value_counts().index,df[i].value_counts()).set_title(i)
    plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
group=df.groupby([])
